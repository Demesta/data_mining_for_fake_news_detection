# %%
import os
import gensim
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
train_data = pd.read_csv('./train.csv')
test_data = pd.read_csv('./test.csv')

# %%
train_data
# Out:
#     Unnamed: 0                                              title  \
# 0            0  Obama’s Delusion Continues In Vapid Address To...
# 1            1  Huge blast in China's Ningbo city kills at lea...
# 2            2  Trump applauds senators for new healthcare ref...
# 3            3  UAW chief says Clinton told him she would rene...
# 4            4  The Las Vegas Mass Shooting – More to the Stor...
# ..         ...                                                ...
# 95          95  Spain gives Catalan leader five days to clarif...
# 96          96   WATCH: Van Jones Says EXACTLY What Needs To B...
# 97          97  LIKE MOTHER, LIKE DAUGHTER: Chelsea Proves She...
# 98          98   WATCH: Racist Republican Congressman Steve Ki...
# 99          99  Virginia governor vetoes religious protection ...
#
#                                                  text       subject  \
# 0   Obama addressed the Nation In a nothing burger...      politics
# 1   BEIJING (Reuters) - A powerful explosion in a ...     worldnews
# 2   WASHINGTON (Reuters) - President Donald Trump ...  politicsNews
# 3   (Reuters) - United Auto Workers President Denn...  politicsNews
# 4   Shawn Helton 21st Century WireAlthough many ar...       US_News
# ..                                                ...           ...
# 95  MADRID (Reuters) - The Spanish government has ...     worldnews
# 96  The election result tonight is hard to swallow...          News
# 97  If what we say reflects on how our parents rai...      politics
# 98  It doesn t get any clearer than this that Iowa...          News
# 99  (Reuters) - Virginia Governor Terry McAuliffe ...  politicsNews
#
#                    date  label
# 0           Dec 6, 2015      0
# 1    November 26, 2017       1
# 2   September 13, 2017       1
# 3        July 26, 2016       1
# 4      October 12, 2017      0
# ..                  ...    ...
# 95    October 11, 2017       1
# 96     November 9, 2016      0
# 97         Feb 19, 2017      0
# 98        July 12, 2016      0
# 99      March 30, 2016       1
#
# [100 rows x 6 columns]

# %%
w2v = gensim.models.Word2Vec(train_data['text'],
                             vector_size=200,
                             window=5,
                             min_count=2,
                             sg=1,
                             negative=10,
                             workers=2,
                             seed=34)
